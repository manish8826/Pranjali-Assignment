# %%
#TASK Pranjali Enterprises :


#DATA PRE-PROCESSING:


#Data importing:

# %%
import pandas as pd

# %%
pranjali = pd.read_csv(r"C:\Users\91882\Downloads\GFDLNFO_BACKADJUSTED_03012022.csv")

# %%
pranjali
# Out:
#                            Ticker        Date      Time    Open    High  \
# 0       AARTIIND27JAN221000CE.NFO  03/01/2022  09:15:59   38.00   40.05
# 1       AARTIIND27JAN221000CE.NFO  03/01/2022  09:16:59   42.00   42.00
# 2       AARTIIND27JAN221000CE.NFO  03/01/2022  09:17:59   38.05   40.85
# 3       AARTIIND27JAN221000CE.NFO  03/01/2022  09:18:59   41.45   42.50
# 4       AARTIIND27JAN221000CE.NFO  03/01/2022  09:19:59   42.75   43.00
# ...                           ...         ...       ...     ...     ...
# 698088                ZEEL-II.NFO  03/01/2022  15:27:59  325.80  325.80
# 698089                ZEEL-II.NFO  03/01/2022  15:29:59  325.55  325.55
# 698090               ZEEL-III.NFO  03/01/2022  09:32:59  326.50  327.00
# 698091               ZEEL-III.NFO  03/01/2022  11:56:59  327.00  328.15
# 698092               ZEEL-III.NFO  03/01/2022  12:44:59  328.15  328.15
#
#            Low   Close  Volume  Open Interest
# 0        37.00   37.00    5100         212500
# ...

# %%
pranjali.head() #Checking top 5 records of data
# Out:
#                       Ticker        Date      Time   Open   High    Low  \
# 0  AARTIIND27JAN221000CE.NFO  03/01/2022  09:15:59  38.00  40.05  37.00
# 1  AARTIIND27JAN221000CE.NFO  03/01/2022  09:16:59  42.00  42.00  38.05
# 2  AARTIIND27JAN221000CE.NFO  03/01/2022  09:17:59  38.05  40.85  38.05
# 3  AARTIIND27JAN221000CE.NFO  03/01/2022  09:18:59  41.45  42.50  39.30
# 4  AARTIIND27JAN221000CE.NFO  03/01/2022  09:19:59  42.75  43.00  42.75
#
#    Close  Volume  Open Interest
# 0  37.00    5100         212500
# 1  38.05    3400         212500
# 2  39.30    5100         211650
# 3  42.50   18700         211650
# 4  43.00    6800         211650

# %%
pranjali.shape #Total number of data(rows and column)
# Out:
# (698093, 9)

# %%
pranjali.index #Showing index
# Out:
# RangeIndex(start=0, stop=698093, step=1)

# %%
pranjali.dtypes #Checking data type of each column
# Out:
# Ticker            object
# Date              object
# Time              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# Open Interest      int64
# dtype: object

# %%
pranjali["Ticker"].unique() #finding unique values in Ticker column
# Out:
# array(['AARTIIND27JAN221000CE.NFO', 'AARTIIND27JAN221000PE.NFO',
#        'AARTIIND27JAN221010CE.NFO', ..., 'ZEEL-I.NFO', 'ZEEL-II.NFO',
#        'ZEEL-III.NFO'], dtype=object)

# %%
pranjali.count() #for finding null values
# Out:
# Ticker           698093
# Date             698093
# Time             698093
# Open             698093
# High             698093
# Low              698093
# Close            698093
# Volume           698093
# Open Interest    698093
# dtype: int64

# %%
#Ans : there is no null value in table

# %%
pranjali["Ticker"].value_counts()
# Out:
# BANKNIFTY06JAN2236200PE.NFO    376
# NIFTY06JAN2217850CE.NFO        376
# NIFTY06JAN2217800CE.NFO        376
# BANKNIFTY06JAN2234400PE.NFO    376
# BANKNIFTY06JAN2234500PE.NFO    376
#                               ...
# NTPC27JAN22135PE.NFO             1
# INDIGO27JAN221800CE.NFO          1
# BANKBARODA24FEB2280PE.NFO        1
# DLF24FEB22360PE.NFO              1
# POWERGRID27JAN22195CE.NFO        1
# Name: Ticker, Length: 8418, dtype: int64

# %%
#Que1. Filtering BANKNIFTY-I.NFO from Ticker column

# %%
#Ans. There are 376 records 

pranjali[pranjali.Ticker == "BANKNIFTY-I.NFO"]
# Out:
#                  Ticker        Date      Time      Open      High       Low  \
# 162329  BANKNIFTY-I.NFO  03/01/2022  09:15:59  36621.00  36621.00  35708.05
# 162330  BANKNIFTY-I.NFO  03/01/2022  09:16:59  35813.95  35825.75  35798.70
# 162331  BANKNIFTY-I.NFO  03/01/2022  09:17:59  35796.55  35796.90  35757.40
# 162332  BANKNIFTY-I.NFO  03/01/2022  09:18:59  35782.60  35834.25  35782.60
# 162333  BANKNIFTY-I.NFO  03/01/2022  09:19:59  35830.50  35839.65  35823.40
# ...                 ...         ...       ...       ...       ...       ...
# 162700  BANKNIFTY-I.NFO  03/01/2022  15:26:59  36618.10  36619.95  36608.95
# 162701  BANKNIFTY-I.NFO  03/01/2022  15:27:59  36618.20  36625.00  36617.35
# 162702  BANKNIFTY-I.NFO  03/01/2022  15:28:59  36622.00  36631.85  36618.10
# 162703  BANKNIFTY-I.NFO  03/01/2022  15:29:59  36628.50  36642.00  36624.60
# 162704  BANKNIFTY-I.NFO  03/01/2022  15:30:59  36640.00  36644.00  36640.00
#
#            Close  Volume  Open Interest
# ...

# %%
#Que2. Convert Date and Time into a new datetime column

# %%
#Ans. 
pranjali['Date'] + ' ' + pranjali['Time']
# Out:
# 0         2022-01-03 09:15:59
# 1         2022-01-03 09:16:59
# 2         2022-01-03 09:17:59
# 3         2022-01-03 09:18:59
# 4         2022-01-03 09:19:59
#                  ...
# 698088    2022-01-03 15:27:59
# 698089    2022-01-03 15:29:59
# 698090    2022-01-03 09:32:59
# 698091    2022-01-03 11:56:59
# 698092    2022-01-03 12:44:59
# Length: 698093, dtype: object

# %%
pranjali.head()
# Out:
#                       Ticker        Date      Time   Open   High    Low  \
# 0  AARTIIND27JAN221000CE.NFO  2022-01-03  09:15:59  38.00  40.05  37.00
# 1  AARTIIND27JAN221000CE.NFO  2022-01-03  09:16:59  42.00  42.00  38.05
# 2  AARTIIND27JAN221000CE.NFO  2022-01-03  09:17:59  38.05  40.85  38.05
# 3  AARTIIND27JAN221000CE.NFO  2022-01-03  09:18:59  41.45  42.50  39.30
# 4  AARTIIND27JAN221000CE.NFO  2022-01-03  09:19:59  42.75  43.00  42.75
#
#    Close  Volume  Open Interest             Datetime
# 0  37.00    5100         212500  03/01/2022 09:15:59
# 1  38.05    3400         212500  03/01/2022 09:16:59
# 2  39.30    5100         211650  03/01/2022 09:17:59
# 3  42.50   18700         211650  03/01/2022 09:18:59
# 4  43.00    6800         211650  03/01/2022 09:19:59

# %%
#Que3: Delete column Ticker ,Date,Time,Volume,Open Interest

# %%
#Ans: After deleting columns


pranjali.head()
# Out:
#     Open   High    Low  Close             Datetime
# 0  38.00  40.05  37.00  37.00  03/01/2022 09:15:59
# 1  42.00  42.00  38.05  38.05  03/01/2022 09:16:59
# 2  38.05  40.85  38.05  39.30  03/01/2022 09:17:59
# 3  41.45  42.50  39.30  42.50  03/01/2022 09:18:59
# 4  42.75  43.00  42.75  43.00  03/01/2022 09:19:59

# %%
pranjali.head()
# Out:
#          Date      Time   Open   High    Low  Close  Volume  Open Interest  \
# 0  2022-01-03  09:15:59  38.00  40.05  37.00  37.00    5100         212500
# 1  2022-01-03  09:16:59  42.00  42.00  38.05  38.05    3400         212500
# 2  2022-01-03  09:17:59  38.05  40.85  38.05  39.30    5100         211650
# 3  2022-01-03  09:18:59  41.45  42.50  39.30  42.50   18700         211650
# 4  2022-01-03  09:19:59  42.75  43.00  42.75  43.00    6800         211650
#
#               Datetime
# 0  03/01/2022 09:15:59
# 1  03/01/2022 09:16:59
# 2  03/01/2022 09:17:59
# 3  03/01/2022 09:18:59
# 4  03/01/2022 09:19:59

# %%
#Now renaming Datetime to date_time:

pranjali.rename(columns={"Datetime": "date_time"}, inplace=True)

# %%
#Que4:sort data datetime:

#Ans:

pranjali = pranjali.sort_values('date_time')

# %%
pranjali.head()
# Out:
#            Open     High      Low    Close            date_time
# 0         38.00    40.05    37.00    37.00  03/01/2022 09:15:59
# 152945   504.65   515.10   504.65   515.10  03/01/2022 09:15:59
# 572878     9.80     9.80     9.20     9.40  03/01/2022 09:15:59
# 153175  1100.05  1101.85  1100.00  1101.85  03/01/2022 09:15:59
# 572660    19.85    19.85    19.85    19.85  03/01/2022 09:15:59
